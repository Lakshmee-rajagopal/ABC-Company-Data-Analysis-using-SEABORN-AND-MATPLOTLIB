# %% [markdown]
# # As a culminating project, you'll be working with a dataset from ABC company, consisting of 458 rows and 9 columns. The company requires a comprehensive report detailing information about their employees across various teams. Your tasks include preprocessing the dataset, analyzing the data, and presenting your findings graphically. Here's a breakdown of what you need to do:
#
# Preprocessing:
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis. (1 mark)
#
# Analysis Tasks:
# 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees. (2 marks)
# 2. Segregate employees based on their positions within the company. (2 marks)
# 3. Identify the predominant age group among employees. (2 marks)
# 4. Discover which team and position have the highest salary expenditure. (2 marks)
# 5. Investigate if there's any correlation between age and salary, and represent it visually. (2 marks)
#
# Graphical Representation:
# For each of the five analysis tasks, create appropriate visualizations to present your findings effectively. (5x2 = 10 marks)
#
# Data Story:
# Provide insights gained from the analysis, highlighting key trends, patterns, and correlations within the dataset. (3 marks)
#
# Timely Submission:
# Ensure timely submission of your project to earn an additional mark. (1 mark)
#
# Total Marks : 25

# %%
import pandas as pd
df = pd.read_csv("C:/Users/sheej/OneDrive/Desktop/jupyternotebook/PYTHON COMPREHENSIVE ASSESSMENT/abc_dataset.csv.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Correct the data in the "height" column by replacing it with random numbers between 150 and 180
df['height'] = np.random.randint(150, 181, size=len(df))
df['height']
# Out:
# 0      153
# 1      154
# 2      166
# 3      169
# 4      151
#       ...
# 453    159
# 454    167
# 455    163
# 456    171
# 457    157
# Name: height, Length: 458, dtype: int32

# %%
# ANALYSIS TASKS

# 1.1 Distribution of employees across each team
team_distribution = df['Team'].value_counts()
print(team_distribution)
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
# 1.2 Calculate percentage split relative to the total number of employees

percentage_split = (team_distribution / len(df)) * 100
print(percentage_split)
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
# Visualization for the above questions 1.1 and 1.2
plt.figure(figsize=(10, 6))
sns.barplot(x=percentage_split.index, y=percentage_split.values)
plt.title('Employee Distribution Across Teams')
plt.xlabel('Team')
plt.ylabel('Percentage of Employees')
plt.xticks(rotation=55)
plt.show()

# %%
# 2. Segregate employees based on their positions
position_distribution = df['Position'].value_counts()
print(position_distribution)
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
# Visualization for question 2
plt.figure(figsize=(10, 6))
position_distribution.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Position Distribution')
plt.axis('equal')
plt.show()

# %%
# 3. Identify the predominant age group among employees.

# Define age groups
bins = [20, 30, 40, 50, 60, 70]

# Create age groups
df['age_group'] = pd.cut(df['Age'], bins=bins)

# Calculate frequency of each age group
age_group_frequency = df['age_group'].value_counts()

# Identify age group with the highest frequency
predominant_age_group = age_group_frequency.idxmax()
frequency_of_predominant_age_group = age_group_frequency.max()

print("The predominant age group among employees is:", predominant_age_group)
print("Frequency of the predominant age group:", frequency_of_predominant_age_group)
# Out:
# The predominant age group among employees is: (20, 30]
# Frequency of the predominant age group: 346

# %%
# Visualization for question 3

import matplotlib.pyplot as plt

# Calculate frequency of each age group
age_group_frequency = df['age_group'].value_counts()

# Visualization
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=bins, color='skyblue', edgecolor='black', label='Age Distribution')
plt.axvline(x=predominant_age_group.right, color='red', linestyle='--', linewidth=2, label='Predominant Age Group')
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# 4. Discover which team and position have the highest salary expenditure.

highest_salary_team = df.groupby('Team')['Salary'].sum().idxmax()
highest_salary_position = df.groupby('Position')['Salary'].sum().idxmax()

print("Team with the highest salary expenditure:", highest_salary_team)
print("Position with the highest salary expenditure:", highest_salary_position)
# Out:
# Team with the highest salary expenditure: Cleveland Cavaliers
# Position with the highest salary expenditure: C

# %%
# Visualization for question 4

# Convert to DataFrame or Series
highest_salary_team = df.groupby('Team')['Salary'].sum().reset_index()
highest_salary_position = df.groupby('Position')['Salary'].sum().reset_index()

# Visualization for team with the highest salary expenditure
plt.figure(figsize=(10, 6))
sns.barplot(x='Team', y='Salary', data=highest_salary_team)
plt.title('Total Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.xticks(rotation=45)
plt.show()

# Visualization for position with the highest salary expenditure
plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='Salary', data=highest_salary_position)
plt.title('Total Salary Expenditure by Position')
plt.xlabel('Position')
plt.ylabel('Total Salary Expenditure')
plt.xticks(rotation=45)
plt.show()

# %%
# 5. Investigate if there's any correlation between age and salary, and represent it visually.

# Visualization
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # DATA STORY
#
# Exploring Employee Dynamics at ABC Company
#
# 1. Employee Distribution Across Teams:
# Through a bar plot, we observed that Team New Orleans Pelicans has the highest percentage of employees, followed by Team Memphis Grizzlies and Team Utah Jazz.
#
# 2. Segregation of Employees by Position:
# The pie chart revealed that a significant portion of employees holds the position of SG, followed by PF and PG.
#
# 3. Predominant Age Group Among Employees:
# The histogram analysis showed that the majority of employees fall within the age range of 20 to 30 years.
#
# 4. Salary Expenditure Analysis:
# Through bar plot, it was identified that Team Cleveland Cavaliers and the C position have the highest salary expenditures.
#
# 5. Exploration of Age-Salary Relationship:
# The relationship between age and salary is found out using Scatter Plot. Interesting patterns were found in the distribution of salary across different age groups. First it increases linearly and then it decreases.
